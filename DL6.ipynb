# %%
# a. Data Preparation
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import skipgrams
from tensorflow.keras.layers import Embedding, Dot, Reshape, Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics.pairwise import cosine_similarity

# Sample text corpus (you can replace this with any corpus)
corpus = [
    "the quick brown fox jumps over the lazy dog",
    "the dog is in the garden",
    "the fox is in the forest"
]

# Tokenize the corpus
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
vocab_size = len(tokenizer.word_index) + 1  # Vocabulary size
word_index = tokenizer.word_index
index_word = {v: k for k, v in word_index.items()}  # Reverse mapping for easy access

# Convert sentences to sequences of word indices
sequences = tokenizer.texts_to_sequences(corpus)

# b. Generate Training Data
# Generate context-target pairs for CBOW
window_size = 2  # Number of context words to use on each side of the target word

def generate_context_target_pairs(sequences, window_size):
    context_target_pairs = []
    for sequence in sequences:
        for i, target_word in enumerate(sequence):
            context_words = [
                sequence[j] for j in range(max(0, i - window_size), min(len(sequence), i + window_size + 1))
                if j != i
            ]
            context_target_pairs.append((context_words, target_word))
    return context_target_pairs

context_target_pairs = generate_context_target_pairs(sequences, window_size)

# Prepare the training data for the CBOW model
def prepare_training_data(context_target_pairs, vocab_size):
    X_context = []
    y_target = []
    for context, target in context_target_pairs:
        context_vector = pad_sequences([context], maxlen=2 * window_size)  # Pad to ensure fixed input size
        X_context.append(context_vector.flatten())
        y_target.append(target)
    return np.array(X_context), np.array(y_target)

X_train, y_train = prepare_training_data(context_target_pairs, vocab_size)

# c. Train Model
embedding_dim = 50  # Dimension of the word embeddings

# Define the CBOW model
input_context = Input(shape=(2 * window_size,))
embedding = Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=2 * window_size)(input_context)
average_embedding = tf.reduce_mean(embedding, axis=1)
output = Dense(vocab_size, activation='softmax')(average_embedding)

cbow_model = Model(inputs=input_context, outputs=output)
cbow_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')

# Train the model
cbow_model.fit(X_train, y_train, epochs=100, verbose=2)

# d. Output: Get Word Embeddings and Similarity
# Extract the word embeddings from the model
word_embeddings = cbow_model.get_layer('embedding').get_weights()[0]

# Function to find similar words
def find_similar_words(word, word_embeddings, word_index, index_word, top_n=5):
    word_id = word_index[word]
    word_vector = word_embeddings[word_id].reshape(1, -1)
    similarities = cosine_similarity(word_vector, word_embeddings)
    similar_word_ids = similarities[0].argsort()[-top_n-1:-1][::-1]
    similar_words = [index_word[i] for i in similar_word_ids if i != word_id]
    return similar_words

# Example: Find words similar to "fox"
similar_words = find_similar_words("fox", word_embeddings, word_index, index_word)
print(f"Words similar to 'fox': {similar_words}")
# Out:
# Epoch 1/100
# 1/1 - 1s - loss: 2.5711 - 501ms/epoch - 501ms/step
# Epoch 2/100
# 1/1 - 0s - loss: 2.5672 - 6ms/epoch - 6ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 2.5632 - 5ms/epoch - 5ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 2.5593 - 5ms/epoch - 5ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 2.5553 - 5ms/epoch - 5ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 2.5514 - 5ms/epoch - 5ms/step
# Epoch 7/100
# 1/1 - 0s - loss: 2.5475 - 5ms/epoch - 5ms/step
# Epoch 8/100
# 1/1 - 0s - loss: 2.5435 - 3ms/epoch - 3ms/step
# Epoch 9/100
# 1/1 - 0s - loss: 2.5396 - 5ms/epoch - 5ms/step
# Epoch 10/100
# 1/1 - 0s - loss: 2.5356 - 4ms/epoch - 4ms/step
# Epoch 11/100
# 1/1 - 0s - loss: 2.5317 - 4ms/epoch - 4ms/step
# Epoch 12/100
# 1/1 - 0s - loss: 2.5277 - 3ms/epoch - 3ms/step
# Epoch 13/100
# 1/1 - 0s - loss: 2.5238 - 5ms/epoch - 5ms/step
# Epoch 14/100
# 1/1 - 0s - loss: 2.5198 - 4ms/epoch - 4ms/step
# Epoch 15/100
# 1/1 - 0s - loss: 2.5158 - 4ms/epoch - 4ms/step
# Epoch 16/100
# 1/1 - 0s - loss: 2.5118 - 4ms/epoch - 4ms/step
# Epoch 17/100
# 1/1 - 0s - loss: 2.5078 - 4ms/epoch - 4ms/step
# Epoch 18/100
# 1/1 - 0s - loss: 2.5037 - 3ms/epoch - 3ms/step
# Epoch 19/100
# 1/1 - 0s - loss: 2.4997 - 5ms/epoch - 5ms/step
# Epoch 20/100
# 1/1 - 0s - loss: 2.4956 - 4ms/epoch - 4ms/step
# Epoch 21/100
# 1/1 - 0s - loss: 2.4915 - 4ms/epoch - 4ms/step
# Epoch 22/100
# 1/1 - 0s - loss: 2.4873 - 5ms/epoch - 5ms/step
# Epoch 23/100
# 1/1 - 0s - loss: 2.4832 - 3ms/epoch - 3ms/step
# Epoch 24/100
# 1/1 - 0s - loss: 2.4790 - 3ms/epoch - 3ms/step
# Epoch 25/100
# 1/1 - 0s - loss: 2.4747 - 4ms/epoch - 4ms/step
# Epoch 26/100
# 1/1 - 0s - loss: 2.4704 - 3ms/epoch - 3ms/step
# Epoch 27/100
# 1/1 - 0s - loss: 2.4661 - 3ms/epoch - 3ms/step
# Epoch 28/100
# 1/1 - 0s - loss: 2.4618 - 4ms/epoch - 4ms/step
# Epoch 29/100
# 1/1 - 0s - loss: 2.4574 - 4ms/epoch - 4ms/step
# Epoch 30/100
# 1/1 - 0s - loss: 2.4530 - 4ms/epoch - 4ms/step
# Epoch 31/100
# 1/1 - 0s - loss: 2.4485 - 5ms/epoch - 5ms/step
# Epoch 32/100
# 1/1 - 0s - loss: 2.4440 - 3ms/epoch - 3ms/step
# Epoch 33/100
# 1/1 - 0s - loss: 2.4395 - 5ms/epoch - 5ms/step
# Epoch 34/100
# 1/1 - 0s - loss: 2.4349 - 4ms/epoch - 4ms/step
# Epoch 35/100
# 1/1 - 0s - loss: 2.4303 - 4ms/epoch - 4ms/step
# Epoch 36/100
# 1/1 - 0s - loss: 2.4256 - 5ms/epoch - 5ms/step
# Epoch 37/100
# 1/1 - 0s - loss: 2.4209 - 6ms/epoch - 6ms/step
# Epoch 38/100
# 1/1 - 0s - loss: 2.4161 - 6ms/epoch - 6ms/step
# Epoch 39/100
# 1/1 - 0s - loss: 2.4112 - 3ms/epoch - 3ms/step
# Epoch 40/100
# 1/1 - 0s - loss: 2.4064 - 9ms/epoch - 9ms/step
# Epoch 41/100
# 1/1 - 0s - loss: 2.4015 - 4ms/epoch - 4ms/step
# Epoch 42/100
# 1/1 - 0s - loss: 2.3965 - 4ms/epoch - 4ms/step
# Epoch 43/100
# 1/1 - 0s - loss: 2.3915 - 4ms/epoch - 4ms/step
# Epoch 44/100
# 1/1 - 0s - loss: 2.3864 - 5ms/epoch - 5ms/step
# Epoch 45/100
# 1/1 - 0s - loss: 2.3813 - 7ms/epoch - 7ms/step
# Epoch 46/100
# 1/1 - 0s - loss: 2.3761 - 4ms/epoch - 4ms/step
# Epoch 47/100
# 1/1 - 0s - loss: 2.3708 - 7ms/epoch - 7ms/step
# Epoch 48/100
# 1/1 - 0s - loss: 2.3656 - 6ms/epoch - 6ms/step
# Epoch 49/100
# 1/1 - 0s - loss: 2.3602 - 6ms/epoch - 6ms/step
# Epoch 50/100
# 1/1 - 0s - loss: 2.3548 - 5ms/epoch - 5ms/step
# Epoch 51/100
# 1/1 - 0s - loss: 2.3494 - 7ms/epoch - 7ms/step
# Epoch 52/100
# 1/1 - 0s - loss: 2.3439 - 5ms/epoch - 5ms/step
# Epoch 53/100
# 1/1 - 0s - loss: 2.3384 - 4ms/epoch - 4ms/step
# Epoch 54/100
# 1/1 - 0s - loss: 2.3328 - 3ms/epoch - 3ms/step
# Epoch 55/100
# 1/1 - 0s - loss: 2.3271 - 5ms/epoch - 5ms/step
# Epoch 56/100
# 1/1 - 0s - loss: 2.3214 - 6ms/epoch - 6ms/step
# Epoch 57/100
# 1/1 - 0s - loss: 2.3157 - 3ms/epoch - 3ms/step
# Epoch 58/100
# 1/1 - 0s - loss: 2.3098 - 3ms/epoch - 3ms/step
# Epoch 59/100
# 1/1 - 0s - loss: 2.3040 - 3ms/epoch - 3ms/step
# Epoch 60/100
# 1/1 - 0s - loss: 2.2981 - 4ms/epoch - 4ms/step
# Epoch 61/100
# 1/1 - 0s - loss: 2.2921 - 6ms/epoch - 6ms/step
# Epoch 62/100
# 1/1 - 0s - loss: 2.2861 - 5ms/epoch - 5ms/step
# Epoch 63/100
# 1/1 - 0s - loss: 2.2801 - 5ms/epoch - 5ms/step
# Epoch 64/100
# 1/1 - 0s - loss: 2.2740 - 3ms/epoch - 3ms/step
# Epoch 65/100
# 1/1 - 0s - loss: 2.2678 - 5ms/epoch - 5ms/step
# Epoch 66/100
# 1/1 - 0s - loss: 2.2616 - 6ms/epoch - 6ms/step
# Epoch 67/100
# 1/1 - 0s - loss: 2.2553 - 4ms/epoch - 4ms/step
# Epoch 68/100
# 1/1 - 0s - loss: 2.2490 - 4ms/epoch - 4ms/step
# Epoch 69/100
# 1/1 - 0s - loss: 2.2427 - 5ms/epoch - 5ms/step
# Epoch 70/100
# 1/1 - 0s - loss: 2.2363 - 5ms/epoch - 5ms/step
# Epoch 71/100
# 1/1 - 0s - loss: 2.2299 - 3ms/epoch - 3ms/step
# Epoch 72/100
# 1/1 - 0s - loss: 2.2234 - 4ms/epoch - 4ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 2.2169 - 4ms/epoch - 4ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 2.2103 - 7ms/epoch - 7ms/step
# Epoch 75/100
# 1/1 - 0s - loss: 2.2037 - 3ms/epoch - 3ms/step
# Epoch 76/100
# 1/1 - 0s - loss: 2.1970 - 6ms/epoch - 6ms/step
# Epoch 77/100
# 1/1 - 0s - loss: 2.1904 - 4ms/epoch - 4ms/step
# Epoch 78/100
# 1/1 - 0s - loss: 2.1836 - 4ms/epoch - 4ms/step
# Epoch 79/100
# 1/1 - 0s - loss: 2.1769 - 5ms/epoch - 5ms/step
# Epoch 80/100
# 1/1 - 0s - loss: 2.1701 - 4ms/epoch - 4ms/step
# Epoch 81/100
# 1/1 - 0s - loss: 2.1632 - 3ms/epoch - 3ms/step
# Epoch 82/100
# 1/1 - 0s - loss: 2.1563 - 5ms/epoch - 5ms/step
# Epoch 83/100
# 1/1 - 0s - loss: 2.1494 - 39ms/epoch - 39ms/step
# Epoch 84/100
# 1/1 - 0s - loss: 2.1425 - 3ms/epoch - 3ms/step
# Epoch 85/100
# 1/1 - 0s - loss: 2.1355 - 4ms/epoch - 4ms/step
# Epoch 86/100
# 1/1 - 0s - loss: 2.1285 - 7ms/epoch - 7ms/step
# Epoch 87/100
# 1/1 - 0s - loss: 2.1215 - 5ms/epoch - 5ms/step
# Epoch 88/100
# 1/1 - 0s - loss: 2.1144 - 4ms/epoch - 4ms/step
# Epoch 89/100
# 1/1 - 0s - loss: 2.1073 - 3ms/epoch - 3ms/step
# Epoch 90/100
# 1/1 - 0s - loss: 2.1002 - 4ms/epoch - 4ms/step
# Epoch 91/100
# 1/1 - 0s - loss: 2.0930 - 3ms/epoch - 3ms/step
# Epoch 92/100
# 1/1 - 0s - loss: 2.0858 - 3ms/epoch - 3ms/step
# Epoch 93/100
# 1/1 - 0s - loss: 2.0786 - 4ms/epoch - 4ms/step
# Epoch 94/100
# 1/1 - 0s - loss: 2.0714 - 3ms/epoch - 3ms/step
# Epoch 95/100
# 1/1 - 0s - loss: 2.0641 - 3ms/epoch - 3ms/step
# Epoch 96/100
# 1/1 - 0s - loss: 2.0568 - 3ms/epoch - 3ms/step
# Epoch 97/100
# 1/1 - 0s - loss: 2.0495 - 4ms/epoch - 4ms/step
# Epoch 98/100
# 1/1 - 0s - loss: 2.0422 - 3ms/epoch - 3ms/step
# Epoch 99/100
# 1/1 - 0s - loss: 2.0348 - 3ms/epoch - 3ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 2.0275 - 3ms/epoch - 3ms/step
# Words similar to 'fox': ['the', 'dog', 'forest', 'garden', 'is']
